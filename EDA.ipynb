# %% [markdown]
# EDA

# %% [markdown]
# Exploratory Data Analysis
#
# it is a preliminary step in daya analysis to:
# ->summarize the main characteristic of the data...
# ->gain better understanading of the dataset...
# ->uncover the relationship between thae variables...
# ->extract important variable

# %% [markdown]
# EDA IS USED TO FIND THE ANSWER OF "What are the charateristic that have most impact on the result"

# %% [markdown]
# TABLE OF CONTENT ..."
# Import Data from Module........
# Analyzing Individual Feature Patterns using Visualization......
# Descriptive Statistical Analysis......
# Basics of Grouping........
# Correlation and Causation........AND
# ANOVA

# %%
# Write your code data type of the column 'peak-rpm?'
import pandas as pd
df = pd.read_csv("dataset/supermarket_data.csv")
print(df.dtypes)
# Out:
# Invoice            str
# StockCode          str
# Description        str
# Quantity         int64
# InvoiceDate        str
# Price          float64
# Customer ID    float64
# Country            str
# dtype: object

# %%
# Write your code data type of the column 'quantity?'
df["Quantity"].dtype
# Out:
# dtype('int64')
