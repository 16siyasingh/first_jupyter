# %%
import pandas as p
data = p.read_csv("dataset/supermarket_data.csv")
data.head(15)
# Out:
#    Invoice StockCode                          Description  Quantity  \
# 0   536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1   536365     71053                  WHITE METAL LANTERN         6
# 2   536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3   536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4   536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5   536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6   536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7   536366     22633               HAND WARMER UNION JACK         6
# 8   536366     22632            HAND WARMER RED POLKA DOT         6
# 9   536368     22960             JAM MAKING SET WITH JARS         6
# 10  536368     22913          RED COAT RACK PARIS FASHION         3
# 11  536368     22912       YELLOW COAT RACK PARIS FASHION         3
# 12  536368     22914         BLUE COAT RACK PARIS FASHION         3
# ...

# %% [markdown]
# convert "?" to NaN... usingreplace()method.....syntax:=replace(A,B, inplace="True")....repalce A to B

# %%
import numpy as np

# replace "?" to NaN
data.replace("?", np.nan, inplace = True)
data.head(2)
# Out:
#   Invoice StockCode                         Description  Quantity  \
# 0  536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1  536365     71053                 WHITE METAL LANTERN         6
#
#       InvoiceDate  Price  Customer ID         Country
# 0  01/12/10 08:26   2.55      17850.0  United Kingdom
# 1  01/12/10 08:26   3.39      17850.0  United Kingdom

# %% [markdown]
# Evaluating for Missing Data
# The missing values are converted by default. We use the following functions to identify these missing values. There are two methods to detect missing data:
#
# .isnull()
# .notnull()
# The output is a boolean value indicating whether the value that is passed into the argument is in fact missing data

# %%
missing_data = data.isnull()
missing_data.head()
# Out:
#    Invoice  StockCode  Description  Quantity  InvoiceDate  Price  Customer ID  \
# 0    False      False        False     False        False  False        False
# 1    False      False        False     False        False  False        False
# 2    False      False        False     False        False  False        False
# 3    False      False        False     False        False  False        False
# 4    False      False        False     False        False  False        False
#
#    Country
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False

# %% [markdown]
# Using a for loop in Python, we can quickly figure out the number of missing values in each column. As mentioned above, "True" represents a missing value and "False" means the value is present in the dataset.  In the body of the for loop the method ".value_counts()" counts the number of "True" values.

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# Invoice
# Invoice
# False    541910
# Name: count, dtype: int64
#
# StockCode
# StockCode
# False    541910
# Name: count, dtype: int64
#
# Description
# Description
# False    540409
# True       1501
# Name: count, dtype: int64
#
# Quantity
# Quantity
# False    541910
# Name: count, dtype: int64
#
# InvoiceDate
# InvoiceDate
# False    541910
# Name: count, dtype: int64
#
# Price
# Price
# False    541910
# Name: count, dtype: int64
#
# Customer ID
# Customer ID
# False    406830
# True     135080
# Name: count, dtype: int64
#
# Country
# Country
# False    541910
# Name: count, dtype: int64

# %% [markdown]
# Calculate the mean value for the column

# %% [markdown]
# mean_variable = dataFrame["col"].astype("float").mean(axis =0)
# print("Mean item price:", mean_variable).....this code calculate mean of column and print it

# %%
import pandas as p
data = p.read_csv("dataset/supermarket_data.csv")
data.head(15)
# Out:
#    Invoice StockCode                          Description  Quantity  \
# 0   536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1   536365     71053                  WHITE METAL LANTERN         6
# 2   536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3   536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4   536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5   536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6   536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7   536366     22633               HAND WARMER UNION JACK         6
# 8   536366     22632            HAND WARMER RED POLKA DOT         6
# 9   536368     22960             JAM MAKING SET WITH JARS         6
# 10  536368     22913          RED COAT RACK PARIS FASHION         3
# 11  536368     22912       YELLOW COAT RACK PARIS FASHION         3
# 12  536368     22914         BLUE COAT RACK PARIS FASHION         3
# ...

# %%
mean = data["Price"].astype("float").mean(axis =0)
print("mean of the price:",mean)
# Out:
# mean of the price: 4.611138332933512

# %% [markdown]
# replace Nan to mean

# %% [markdown]
# data["Price"].replace(np.nan, mean, inplace=True)...but there is no missing data show replacement not done

# %% [markdown]
# BINNING:--->Binning is a process of transforming continuous numerical variables into discrete categorical 'bins' for grouped analysis
# .....we perform binng in price column ..OK

# %%
import numpy as np
data["Price"]=data["Price"].astype(int, copy=True)
bins = np.linspace(min(data["Price"]), max(data["Price"]),4)
grp_Name = ['Low','Medium','High']
data['Price-binned'] = p.cut(data['Price'], bins, labels=grp_Name, include_lowest=True )
data[['Price','Price-binned']].head(20)
# Out:
# C:\Users\303421\AppData\Local\Temp\ipykernel_16848\3522508766.py:2: Pandas4Warning: The copy keyword is deprecated and will be removed in a future version. Copy-on-Write is active in pandas since 3.0 which utilizes a lazy copy mechanism that defers copies until necessary. Use .copy() to make an eager copy if necessary.
#   data["Price"]=data["Price"].astype(int, copy=True)
#     Price Price-binned
# 0       2          Low
# 1       3          Low
# 2       2          Low
# 3       3          Low
# 4       3          Low
# 5       7          Low
# 6       4          Low
# 7       1          Low
# 8       1          Low
# 9       4          Low
# 10      4          Low
# 11      4          Low
# 12      4          Low
# 13      1          Low
# 14      2          Low
# 15      2          Low
# 16      3          Low
# 17      1          Low
# 18      4          Low
# 19      4          Low

# %%
max(data["Price"])
data.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1  536365     71053                  WHITE METAL LANTERN         6
# 2  536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3  536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4  536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  Price  Customer ID         Country Price-binned
# 0  01/12/10 08:26      2      17850.0  United Kingdom          Low
# 1  01/12/10 08:26      3      17850.0  United Kingdom          Low
# 2  01/12/10 08:26      2      17850.0  United Kingdom          Low
# 3  01/12/10 08:26      3      17850.0  United Kingdom          Low
# 4  01/12/10 08:26      3      17850.0  United Kingdom          Low

# %%
for maxi in missing_data.max(data["Price"]).values.tolist():
    print(maxi)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 for maxi in missing_data.max(data["Price"]).values.tolist():
#       2     print(maxi)
#
# NameError: name 'missing_data' is not defined
